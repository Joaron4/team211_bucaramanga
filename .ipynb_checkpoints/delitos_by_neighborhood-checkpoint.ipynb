# %%
import numpy as np
import pandas as pd
import re
import branca
import folium
import json

# %%
delitos = pd.read_csv('https://www.datos.gov.co/api/views/75fz-q98y/rows.csv?accessType=DOWNLOAD&bom=true&format=true')
# Out:
# /Users/giovannydelacruz/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
delitos
# Out:
#          ORDEN                 ARMAS_MEDIOS           BARRIOS_HECHO   LATITUD  \
# 0            1  ARMA BLANCA / CORTOPUNZANTE            BUENOS AIRES  7.170557
# 1            2  ARMA BLANCA / CORTOPUNZANTE           CAMPO HERMOSO  7.120645
# 2            3  ARMA BLANCA / CORTOPUNZANTE           CAMPO HERMOSO  7.120645
# 3            4  ARMA BLANCA / CORTOPUNZANTE               COMUNEROS  7.151359
# 4            5  ARMA BLANCA / CORTOPUNZANTE                GIRARDOT  7.170557
# ...        ...                          ...                     ...       ...
# 135071  135072          SIN EMPLEO DE ARMAS      CABECERA DEL LLANO       NaN
# 135072  135073                ARMA DE FUEGO  JARDINES DE COAVICONSA       NaN
# 135073  135074                ARMA DE FUEGO                PROVENZA       NaN
# 135074  135075  ARMA BLANCA / CORTOPUNZANTE            TOLEDO PLATA       NaN
# 135075  135076                     PALANCAS          LA GRAN LADERA       NaN
#
#          LONGITUD        ZONA              NOM_COMUNA   ANO            MES  \
# 0      -73.135108      URBANA           14. Morrorico  2010      01. Enero
# 1       -73.12605      URBANA       05. García Rovira  2010      01. Enero
# 2       -73.12605      URBANA       05. García Rovira  2010      01. Enero
# 3      -73.145705      URBANA       03. San Francisco  2010      01. Enero
# 4      -73.135108      URBANA          04. Occidental  2010      01. Enero
# ...           ...         ...                     ...   ...            ...
# 135071        NaN  NO REPORTA  12. Cabecera del Llano  2021  12. Diciembre
# 135072        NaN  NO REPORTA                 11. Sur  2021  12. Diciembre
# 135073        NaN  NO REPORTA            10. Provenza  2021  12. Diciembre
# 135074        NaN  NO REPORTA                 11. Sur  2021  12. Diciembre
# 135075        NaN  NO REPORTA               17. Mutis  2021  12. Diciembre
#
#         DIA   DIA_SEMANA               DESCRIPCION_CONDUCTA  \
# 0         1  05. Viernes  ARTÍCULO 111. LESIONES PERSONALES
# 1         1  05. Viernes  ARTÍCULO 111. LESIONES PERSONALES
# 2         1  05. Viernes  ARTÍCULO 111. LESIONES PERSONALES
# 3         1  05. Viernes  ARTÍCULO 111. LESIONES PERSONALES
# 4         1  05. Viernes  ARTÍCULO 111. LESIONES PERSONALES
# ...     ...          ...                                ...
# 135071   31  05. Viernes     ARTÍCULO 239. HURTO A PERSONAS
# 135072   31  05. Viernes     ARTÍCULO 239. HURTO A PERSONAS
# 135073   31  05. Viernes     ARTÍCULO 239. HURTO A PERSONAS
# 135074   31  05. Viernes     ARTÍCULO 239. HURTO A PERSONAS
# 135075   31  05. Viernes  ARTÍCULO 239. HURTO A RESIDENCIAS
#
#                    CONDUCTA CLASIFICACIONES DELITO EDAD CURSO_DE_VIDA  \
# 0       LESIONES PERSONALES    Lesiones no fatales   30   05. Adultez
# 1       LESIONES PERSONALES    Lesiones no fatales   21   04. Jovenes
# 2       LESIONES PERSONALES    Lesiones no fatales   23   04. Jovenes
# 3       LESIONES PERSONALES    Lesiones no fatales   36   05. Adultez
# 4       LESIONES PERSONALES    Lesiones no fatales   20   04. Jovenes
# ...                     ...                    ...  ...           ...
# 135071     HURTO A PERSONAS    Lesiones no fatales   25   04. Jovenes
# 135072     HURTO A PERSONAS    Lesiones no fatales   21   04. Jovenes
# 135073     HURTO A PERSONAS    Lesiones no fatales   25   04. Jovenes
# 135074     HURTO A PERSONAS    Lesiones no fatales   47   05. Adultez
# 135075  HURTO A RESIDENCIAS    Lesiones no fatales   45   05. Adultez
#
#        ESTADO_CIVIL_PERSONA      GENERO MOVIL_AGRESOR          MOVIL_VICTIMA
# 0               UNION LIBRE   MASCULINO         A PIE                  A PIE
# 1                   SOLTERO   MASCULINO         A PIE                  A PIE
# 2                   SOLTERO   MASCULINO         A PIE                  A PIE
# 3                    CASADO   MASCULINO         A PIE                  A PIE
# 4               UNION LIBRE   MASCULINO         A PIE                  A PIE
# ...                     ...         ...           ...                    ...
# 135071           NO REPORTA  NO REPORTA         A PIE   PASAJERO MOTOCICLETA
# 135072           NO REPORTA  NO REPORTA         A PIE  CONDUCTOR MOTOCICLETA
# 135073           NO REPORTA  NO REPORTA         A PIE  CONDUCTOR MOTOCICLETA
# 135074           NO REPORTA  NO REPORTA         A PIE                  A PIE
# 135075           NO REPORTA    FEMENINO         A PIE     CONDUCTOR VEHICULO
#
# [135076 rows x 20 columns]

# %%
delitos.columns= delitos.columns.str.lower()

# %%
delitos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135076 entries, 0 to 135075
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   orden                   135076 non-null  int64
#  1   armas_medios            135076 non-null  object
#  2   barrios_hecho           135076 non-null  object
#  3   latitud                 128713 non-null  object
#  4   longitud                128713 non-null  object
#  5   zona                    135076 non-null  object
#  6   nom_comuna              135076 non-null  object
#  7   ano                     135076 non-null  int64
#  8   mes                     135076 non-null  object
#  9   dia                     135076 non-null  int64
#  10  dia_semana              135076 non-null  object
#  11  descripcion_conducta    135076 non-null  object
#  12  conducta                135076 non-null  object
#  13  clasificaciones delito  135076 non-null  object
#  14  edad                    135076 non-null  object
#  15  curso_de_vida           135076 non-null  object
#  16  estado_civil_persona    135076 non-null  object
#  17  genero                  135076 non-null  object
#  18  movil_agresor           135076 non-null  object
#  19  movil_victima           135076 non-null  object
# dtypes: int64(3), object(17)
# memory usage: 20.6+ MB

# %%
delitos['nom_comuna'] = delitos['nom_comuna'].str.upper()
delitos['nom_comuna'] = delitos['nom_comuna'].str.replace('.',' -')
# Out:
# /var/folders/s2/7zt_5m2d2nv76vq_ybqf9csm0000gn/T/ipykernel_9252/1842341404.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   delitos['nom_comuna'] = delitos['nom_comuna'].str.replace('.',' -')

# %%
delitos['ano'] = pd.to_datetime(delitos['ano'], format="%Y").dt.year

# %%
delitos["mes"] = delitos['mes'].str[0:2].astype(int)

# %%
order = '[^0-9]'
dia= list(delitos['dia_semana'].str.lower())
dias_clean = []
for i in range(len(dia)):
    
    filtered_string = re.sub(order,'',dia[i])
    dias_clean.append(filtered_string.lstrip())        

dias_clean = pd.Series(dias_clean)

# %%
delitos['dia_semana'] = pd.to_datetime(dias_clean, format="%d").dt.day

# %%
delitos["armas_medios"].replace("NO REPORTADO",np.nan, inplace = True)
delitos["barrios_hecho"].replace("sin informacion",np.nan, inplace = True)
delitos["zona"].replace("NO REPORTA",np.nan, inplace = True)
delitos["nom_comuna"].replace("SIN INFORMACION",np.nan, inplace = True)
delitos["descripcion_conducta"].replace("NO REPORTA",np.nan, inplace = True)
delitos["conducta"].replace("NO REPORTA",np.nan, inplace = True)
delitos["clasificaciones delito"].replace("NO REPORTA",np.nan, inplace = True)
delitos["edad"].replace("NO REPORTA",np.nan, inplace = True)
delitos["curso_de_vida"].replace(["NO REPORTA","ERROR: #N/A"],np.nan, inplace = True)
delitos["estado_civil_persona"].replace("NO REPORTA",np.nan, inplace = True)
delitos["genero"].replace("NO REPORTA",np.nan, inplace = True)
delitos["movil_agresor"].replace("NO REPORTA",np.nan, inplace = True)
delitos["movil_victima"].replace("NO REPORTA",np.nan, inplace = True)

# %%
delitos["barrios_hecho"] =delitos["barrios_hecho"].str.upper()

# %% [markdown]
# Se pasara a filtrar y dejar unicamente los barrios de la alerta temprana.

# %%
delitos["barrios_hecho"].sort_values().unique()
# Out:
# array(['12 DE OCTUBRE', '13 DE JUNIO', '20 DE JULIO', '23 DE JUNIO',
#        '5 DE ENERO', 'ACACIAS', 'AFRICA', 'ALARCON', 'ALBANIA',
#        'ALFONSO LOPEZ', 'ALTO VIENTO', 'ALTO VIENTO I', 'ALTO VIENTO II',
#        'ALTOS DE CAÑAVERAL CAMPESTRE', 'ALTOS DE CAÑAVERAL I',
#        'ALTOS DEL CACIQUE', 'ALTOS DEL CAMPESTRE', 'ALTOS DEL KENNEDY',
#        'ALTOS DEL PROGRESO', 'ALVAREZ', 'ALVAREZ LAS AMERICAS',
#        'ANDALUCIA', 'ANILLO VIAL', 'ANTIGUA COLOMBIA',
#        'ANTIGUO CAMPESTRE', 'ANTIGUO COLOMBIA', 'ANTONIA SANTOS',
#        'ANTONIA SANTOS CENTRO', 'ANTONIA SANTOS SUR',
#        'ASENTAMIENTO SERVIUNON', 'ASENTAMIENTO SERVUNION', 'ASTURIAS',
#        'AUTOPISTA F/BLANCA-P/CUESTA.', 'AUTOPISTA P/CUESTA - F/BLANCA.',
#        'BALCON DEL LAGO', 'BALCON DEL TEJAR', 'BALCONCITOS',
#        'BALCONES DEL KENNEDY', 'BALCONES DEL SUR', 'BARRIO NUEVO',
#        'BAVARIA', 'BELLAVISTA', 'BELLAVISTA CASAS', 'BELLAVISTA FLORIDA',
#        'BETANIA', 'BOLARQUI', 'BOLIVAR', 'BONANZA CAMPESTRE (COLORADOS)',
#        'BOSCONIA', 'BOSQUE NORTE', 'BOSQUES DEL PAYADOR',
#        'BOULEVAR DEL CACIQUE', 'BRISAS DE PROVENZA', 'BRISAS DEL CAMPO',
#        'BRISAS DEL MUTIS', 'BRISAS DEL PALMAR', 'BRISAS DEL PARAISO',
#        'BUCARAMANGA', 'BUENAVISTA', 'BUENOS AIRES', 'BULEVAR DEL CACIQUE',
#        'C.R. SERREZUELA', 'C.R. SOLERI', 'C.R. VERSALLES REAL',
#        'CABECERA DEL LLANO', 'CACIQUE CONDOMINIO', 'CACIQUE IMPERIAL',
#        'CACIQUE IPANA', 'CAFE MADRID', 'CALDAS', 'CALLE REAL',
#        'CAMILO TORRES', 'CAMPESTRE', 'CAMPESTRE NORTE (COLORADOS)',
#        'CAMPO GALAN', 'CAMPO HERMOSO', 'CAMPO MADRID',
#        'CAMPO VALDES 1  C-4', 'CAMPO VERDE', 'CANDILES', 'CANELOS',
#        'CARLOS PIZARRO', 'CARRASCO', 'CASCO ANTIGUO DE FLORIDABLANCA',
#        'CAÑAVERAL', 'CENFER', 'CENTAUROS', 'CENTRAL DE ABASTOS', 'CENTRO',
#        'CENTRO P/TA', 'CHAPINERO', 'CHIMITA', 'CHORRERAS DE DON JUAN',
#        'CIUDAD METROPOLITANA', 'CIUDAD VENECIA',
#        'CIUDADELA LOS PRINCIPES', 'CIUDADELA REAL DE MINAS', 'CLAVERIANO',
#        'COLORADOS', 'COLSEGUROS NORTE', 'COMUNEROS', 'CONDADO CAMPESTRE',
#        'CONDADO DE GIBRALTAR', 'CONQUISTADORES', 'CONUCOS',
#        'CORDONCILLO I', 'CORDONCILLO II', 'DANGOND', 'DELICIAS',
#        'DELICIAS ALTAS', 'DIAMANTE I', 'DIAMANTE II',
#        'DIVINO NIÑO (COLORADOS)', 'DON BOSCO', 'EL BOSQUESITO',
#        'EL CARMEN I', 'EL CARMEN V', 'EL CENTRO', 'EL CINAL',
#        'EL CRISTAL', 'EL DIVISO', 'EL DORADO', 'EL FONCE',
#        'EL GALLINERAL', 'EL JARDIN', 'EL LLANITO', 'EL PABLON',
#        'EL PABLON ( LA TORRE )', 'EL PABLON ( VILLA LINA )',
#        'EL PABLON ( VILLA PATRICIA )', 'EL PALENQUE', 'EL PARAISO',
#        'EL PORVENIR', 'EL PRADO', 'EL PROGRESO', 'EL REPOSO', 'EL RETIRO',
#        'EL ROCIO', 'EL ROSAL', 'EL TEJAR', 'EL UVO', 'ESPAÑA',
#        'ESPERANZA I', 'ESPERANZA II', 'ESPERANZA III', 'ESTORAQUES',
#        'FACULTAD DE MINAS U. NACIONAL C-7', 'FATIMA', 'FONTANA', 'GAITAN',
#        'GALAN', 'GALLINERAL', 'GARCIA ROVIRA', 'GIRARDOT', 'GOMEZ NIÑO',
#        'GRANADA', 'GRANJAS DE JULIO RINCON', 'GRANJAS DE PROVENZA',
#        'GRANJAS REGAN', 'GRANJAS RIGAN', 'GUADUALES', 'GUAYACANES',
#        'HACIENDA DEL CACIQUE', 'HACIENDA SAN JUAN', 'HOYO CHIQUITO',
#        'IGSABELAR', 'INEM', 'INV. CAMINOS DE PAZ', 'INV. CARLOS PIZARRO',
#        'INV. CLUB CHIMITA', 'INV. DELICIAS', 'INV. LOS CORRALES',
#        'INV. LUZ DE ESPERANZA', 'INV. LUZ DE SALVACION',
#        'INV. NUEVO HORIZONTE', 'INV. PAISAJES DEL NORTE',
#        'INV. PUENTE NARIÑO', 'INV. PUNTA BETIN',
#        'INV. QUEBRADA LA IGLESIA', 'INV. SERVUNION', 'INV. TIBURONES',
#        'INV. VILLAS DEL GIRARDOT', 'INVASION GALLINERAL',
#        'JARDINES DE ALTA GRACIA', 'JARDINES DE COAVICONSA',
#        'JOSE ANTONIO GALAN', 'JOSE MARIA CORDOBA', 'JUAN XXIII',
#        'KENEDDY', 'KENNEDY', 'LA AURORA', 'LA CAMPIÑA', 'LA CEIBA',
#        'LA CEMENTO', 'LA CONCORDIA', 'LA ESTRELLA', 'LA FERIA',
#        'LA FLORA', 'LA FLORESTA', 'LA FORTUNA', 'LA GLORIA',
#        'LA GRAN LADERA', 'LA GRANJITA', 'LA INDEPENDENCIA',
#        'LA INMACULADA', 'LA ISLA', 'LA JOYA', 'LA JUVENTUD',
#        'LA LIBERTAD', 'LA MALAÑA (URBANO)', 'LA PALMA', 'LA PEDREGOSA',
#        'LA QUEBRADA', 'LA ROSITA', 'LA SALLE', 'LA UNIVERSIDAD',
#        'LA VICTORIA', 'LAGOS DEL CACIQUE', 'LAS AMERICAS', 'LAS CASITAS',
#        'LAS COLINAS', 'LAS DELICIAS', 'LAS GRANJITAS B/GA',
#        'LAS GUACAMAYAS', 'LAS HAMACAS', 'LAS MARGARITAS MUTIS',
#        'LAURELES', 'LIMONCITO', 'LIZCANO I', 'LIZCANO II', 'LOS ACASIOS',
#        'LOS ANGELES', 'LOS CAMBULOS', 'LOS CANELOS', 'LOS CEDROS',
#        'LOS CENTAUROS', 'LOS COMUNEROS', 'LOS GUADUALES', 'LOS PINOS',
#        'LOS PORTALES II', 'LOS ROBLES', 'LOS ROSALES', 'LOS SAUCES',
#        'MALPASO', 'MANUELA BELTRAN', 'MANUELA BELTRAN I',
#        'MANUELA BELTRAN II', 'MANZANARES', 'MARIA AUXILIADORA',
#        'MARIA PAZ', 'MARIANELA', 'MEJORAS PUBLICAS', 'MERCEDES',
#        'MESETAS DEL SANTUARIO', 'METROPOLITANA', 'MILAGRO DE DIOS',
#        'MINUTO DE DIOS', 'MIRADOR', 'MIRADOR DE COLORADOS',
#        'MIRADOR DE SAN JUAN', 'MIRADOR DEL CACIQUE', 'MIRADOR DEL NORTE',
#        'MIRADORES DE SAN LORENZO', 'MIRADORES DEL KENNEDY', 'MIRAFLORES',
#        'MIRAMAR', 'MODELO', 'MONEQUES', 'MONEQUEZ', 'MORAVIA  C-4',
#        'MORRORICO', 'MUTIS', 'MUTUALIDAD', 'NAPOLES', 'NARIÑO', 'NAVAS',
#        'NIZA', 'NORTE BAJO', 'NUEVA COLOMBIA', 'NUEVA GRANADA',
#        'NUEVO COLON', 'NUEVO SOTOMAYOR', 'OLAS ALTAS', 'OLAS BAJAS',
#        'OLAS II', 'OMAGA (SECTOR I )', 'OMAGA (SECTOR II )',
#        'OMAGA (SECTOR III )', 'PABLO VI', 'PABLON ALTO', 'PABLON BAJO',
#        'PALMERAS DEL CACIQUE', 'PAN DE AZUCAR', 'PANTANO I', 'PANTANO II',
#        'PANTANO III', 'PARQUE INDUSTRIAL', 'PATIO BONITO (COLORADOS)',
#        'PAYADOR REAL', 'PEÑON DEL VALLE', 'PIO XII', 'POBLADO',
#        'PORTAL DEL CACIQUE', 'PORTON DEL TEJAR', 'PORVENIR', 'PRIMAVERAL',
#        'PRIMERO DE MAYO', 'PROVENZA', 'PUERTA DEL SOL', 'PUERTO MADERO',
#        'PUERTO RICO', 'PUNTA ESTRELLA', 'PUNTA PARAISO',
#        'QUEBRADA LA IGLESIA', 'QUINTA DANIA', 'QUINTA ESTRELLA',
#        'QUINTA GRANADA', 'QUINTADANIA', 'QUINTAS DEL CACIQUE',
#        'REGADERO NORTE', 'RICAURTE', 'RINCON DE GIRON',
#        'RINCON DE LA PAZ', 'RIO DE ORO II', 'RUITOQUE BAJO', 'SAN ALONSO',
#        'SAN CRISTOBAL', 'SAN FRANCISCO', 'SAN FRANCISCO P/TA',
#        'SAN GERARDO', 'SAN IGNACIO', 'SAN LUIS', 'SAN MARTIN',
#        'SAN MIGUEL', 'SAN PEDRITO', 'SAN PEDRO CLAVER', 'SAN RAFAEL',
#        'SAN RAFAEL P/TA', 'SAN VALENTIN', 'SANTA MARIA',
#        'SANTA MONICA DEL TEJAR', 'SANTANDER', 'SERREZUELA', 'SOTOMAYOR',
#        'TEJADOS', 'TEJAR NORTE', 'TEJAR NORTE (SECTOR I )',
#        'TEJAR NORTE (SECTOR II )', 'TERMINAL DE TRANSPORTES', 'TERRAZAS',
#        'TESOROS DEL CACIQUE', 'TOLEDO PLATA', 'TRANSICION',
#        'TRANSICION I', 'TRANSICION II', 'TRANSICION III', 'TRANSICION IV',
#        'TRANSICION V', 'UNIVERSIDAD', 'URB VILLAS DE SAN PATRICIO',
#        'URB. ACROPOLIS I', 'URB. ACROPOLIS II', 'URB. ACROPOLIS III',
#        'URB. ALTOS DE TAJAMAR', 'URB. BALCONCITOS',
#        'URB. BALCONES DE LA COLINA', 'URB. BALCONES DE PROVENZA',
#        'URB. BAVARIA', 'URB. BRISAS DE PROVENZA', 'URB. BRISAS DEL MUTIS',
#        'URB. CIUDAD BOLIVAR', 'URB. COLSEGUROS NORTE', 'URB. EL SOL I',
#        'URB. EL SOL II', 'URB. ESTORAQUES I', 'URB. ESTORAQUES II',
#        'URB. FATIMA', 'URB. FUNDADORES', 'URB. GETSEMANI', 'URB. HEROES',
#        'URB. LA GRAN LADERA', 'URB. LA HOYADA', 'URB. LOS ALMENDROS',
#        'URB. LOS NARANJOS', 'URB. LOS SAUCES', 'URB. MACAREGUA',
#        'URB. MANZANARES', 'URB. MARSELLA REAL', 'URB. MIRADOR DE FATIMA',
#        'URB. MIRADORES DE LA UIS', 'URB. MONTE REDONDO',
#        'URB. MONTE VERDE', 'URB. NEPTUNO', 'URB. PASEO LA FERIA',
#        'URB. PLAZA MAYOR', 'URB. PLAZUELA REAL', 'URB. PORTOFINO',
#        'URB. PRADOS DEL MUTIS', 'URB. QUINTAS DE SANTANA',
#        'URB. RINCON DEL LAGO', 'URB. ROSA ALTA', 'URB. SAMANES',
#        'URB. SAN FERMIN', 'URB. SAN VALENTIN', 'URB. TERRANOVA',
#        'URB. TORRES DE ALEJANDRÍA', 'URB. TORRES DE MONTERREY',
#        'URB. VIVEROS DE PROVENZA', 'URBANIZACION QUINTAS DEL CACIQUE',
#        'URBANIZACION SANTA BARBARA', 'VDA. 10 DE MAYO', 'VDA. AGUABLANCA',
#        'VDA. ALTO DE LOS PADRES', 'VDA. ANGELINOS', 'VDA. ARGELIA',
#        'VDA. BOLARQUI', 'VDA. CUCHILLA ALTA', 'VDA. EL ABURRIDO',
#        'VDA. EL NOGAL (COLORADOS)', 'VDA. GUALILO ALTO',
#        'VDA. GUALILO BAJO', 'VDA. LA CAPILLA', 'VDA. LA ESMERALDA',
#        'VDA. LA ESPERANZA', 'VDA. LA MALAÑA', 'VDA. LA SABANA',
#        'VDA. LAS MARIAS', 'VDA. LOS CUADROS', 'VDA. LOS SANTOS',
#        'VDA. MAGUEYES', 'VDA. MALPASO', 'VDA. MONSERRATE',
#        'VDA. PEDREGAL', 'VDA. RETIRO CHIQUITO', 'VDA. RETIRO GRANDE',
#        'VDA. RIO DE ORO', 'VDA. ROSA BLANCA', 'VDA. SAN CAYETANO',
#        'VDA. SAN IGNACIO', 'VDA. SAN JOSE', 'VDA. SAN PEDRO ALTO',
#        'VDA. SAN PEDRO BAJO', 'VDA. SANTA BARBARA', 'VDA. SANTA RITA',
#        'VDA. TRES ESQUINAS', 'VDA. VERICUTE', 'VDA. VIJAGUAL',
#        'VEGAS DE MORRORICO', 'VEGAS DE MORRORRICO', 'VEREDA EL PABLON',
#        'VEREDA MARCELITAS', 'VILLA ALEGRIA', 'VILLA ALICIA',
#        'VILLA CANDADO', 'VILLA DE LOS CABALLEROS',
#        'VILLA DE LOS CONQUISTADORES', 'VILLA DEL NOGAL',
#        'VILLA DEL PRADO', 'VILLA ESMERALDA', 'VILLA FLOR', 'VILLA HELENA',
#        'VILLA HELENA I', 'VILLA HELENA II', 'VILLA INES', 'VILLA MARIA',
#        'VILLA MARIA III (BAJA)', 'VILLA MERCEDES', 'VILLA REAL',
#        'VILLA ROMERO', 'VILLA ROSA', 'VILLA ROSA (SECTOR II )',
#        'VILLA ROSA (SECTOR III )', 'VILLA SARA', 'VILLABEL',
#        'VILLAS DE SAN FRANCISCO', 'VILLAS DE SAN IGNACIO',
#        'VILLAS DEL NOGAL', 'VRDA  ABEJAS', 'VRDA  CAPILLA',
#        'VRDA  JABONCILLO', 'VRDA  SAN ISIDRO', 'ZARABANDA',
#        'ZONA INDUSTRIAL', nan], dtype=object)

# %%
barrios_alertatemprana = ["12 DE OCTUBRE","13 DE JUNIO","23 DE JUNIO","5 DE ENERO","ALARCON","BETANIA","ALTOS DEL KENNEDY","ALTOS DEL PROGRESO","BALCONES DEL KENNEDY",
                        "BARRIO NUEVO","BOSQUE NORTE","BUENOS AIRES","CAFE MADRID","CAMILO TORRES","CAMPO MADRID","CARLOS PIZARRO","CHAPINERO","CLAVERIANO","COLORADOS",
                        "COMUNEROS","DIVINO NIÑO","DON BOSCO","EL CINAL","EL ROSAL","EL PABLÓN","LA ESPERANZA I","LA ESPERANZA II", "LA ESPERANZA III","ESTORAQUES",
                        "GAITAN","GALLINERAL","GIRARDOT","GRANADA","JOSE ANTONIO GALAN","JOSE MARIA CORDOBA","KENNEDY","LA FERIA","LA GLORIA","LA INDEPENDENCIA",
                        "LA JUVENTUD","LA INMACULADA","LA UNIVERSIDAD","LAS HAMACAS","OLAS ALTAS","OLAS BAJAS","LIZCANO I","LIZCANO II","LOS ANGELES","MARIA PAZ",
                        "MESETAS DEL SANTUARIO","MINUTO DE DIOS","MIRAFLORES","MIRADOR","MIRADOR DEL KENNEDY","MIRAMAR","MODELO","MORRORICO","MUTUALIDAD","NAPOLES","NARIÑO",
                        "NAVAS","NORTE BAJO","OLAS II","OMAGA I","OMAGA II","PIO XII","PRIMAVERAL","PUERTO RICO","QUEBRADA LA IGLESIA I","REGADERO NORTE","RINCON DE LA PAZ",
                        "SAN CRISTOBAL","SAN RAFAEL","SAN MARTIN","SAN PEDRO CLAVER","SANTANDER","TEJAR NORTE","TRANSICION","TRANSICION I","TRANSICION II","TRANSICION III",
                        "TRANSICION IV","TRANSICION V","VILLA HELENA I","VILLA HELENA II","VILLA HELENA","VILLA ROSA","VILLA MARIA I","VILLA MARIA III", "VILLA MERCEDES",
                        "VILLA ROSA","VILLAS DE GIRARDOT", "ZARABANDA"]

# %% [markdown]
# El diccionario con las variables a cambiar:

# %%
barrios_cambiar = {
    "DIVINO NIÑO (COLORADOS)": "DIVINO NIÑO",
    "EL PABLON": "EL PABLÓN",
    "EL PABLON ( LA TORRE )": "EL PABLÓN",
    "EL PABLON ( VILLA LINA )": "EL PABLÓN",
    "EL PABLON ( VILLA PATRICIA )": "EL PABLÓN",
    "ESPERANZA I": "LA ESPERANZA I",
    "ESPERANZA II": "LA ESPERANZA II",
    "ESPERANZA III": "LA ESPERANZA III",
    "MIRADORES DEL KENNEDY": "MIRADOR DEL KENNEDY",
    "OMAGA (SECTOR I )": "OMAGA I",
    "OMAGA (SECTOR II )": "OMAGA II",
    "QUEBRADA LA IGLESIA": "QUEBRADA LA IGLESIA I",
    "TEJAR NORTE (SECTOR I )" : "TEJAR NORTE",
    "TEJAR NORTE (SECTOR II )" : "TEJAR NORTE",
    "VILLA MARIA" : "VILLA MARIA I",
    "VILLA MARIA III (BAJA)":"VILLA MARIA III",
    "VILLA ROSA (SECTOR II )":"VILLA ROSA",
    "VILLA ROSA (SECTOR III )":"VILLA ROSA",
    "INV. VILLAS DEL GIRARDOT" : "VILLAS DE GIRARDOT"
}

# %%
delitos["barrios_hecho"] = delitos["barrios_hecho"].replace(barrios_cambiar)

# %%
delitos = delitos[delitos["barrios_hecho"].isin(barrios_alertatemprana)]

# %%
delitos.sample(20)
# Out:
#          orden                 armas_medios       barrios_hecho       latitud  \
# 21645    21646                 CONTUNDENTES      LA UNIVERSIDAD       7.13851
# 121611  121612          SIN EMPLEO DE ARMAS      LA UNIVERSIDAD  7.1363352073
# 86506    86507  ARMA BLANCA / CORTOPUNZANTE            GIRARDOT      7.120302
# 63791    63792                 CONTUNDENTES            LA FERIA      7.122598
# 89972    89973  ARMA BLANCA / CORTOPUNZANTE      TRANSICION III      7.142203
# 96188    96189                ARMA DE FUEGO          SAN MARTIN      7.104995
# 36723    36724                 CONTUNDENTES      VILLA HELENA I      7.152336
# 23179    23180  ARMA BLANCA / CORTOPUNZANTE              GAITAN      7.131711
# 62607    62608  ARMA BLANCA / CORTOPUNZANTE              GAITAN      7.133184
# 59429    59430                ARMA DE FUEGO         CAFE MADRID      7.164545
# 21857    21858                 CONTUNDENTES             GRANADA      7.131711
# 25502    25503                 CONTUNDENTES          NORTE BAJO      7.141422
# 108110  108111          SIN EMPLEO DE ARMAS       LA INMACULADA   7.141889396
# 95244    95245                 CONTUNDENTES      REGADERO NORTE      7.146448
# 60295    60296  ARMA BLANCA / CORTOPUNZANTE             KENNEDY      7.153677
# 124952  124953  ARMA BLANCA / CORTOPUNZANTE          SAN RAFAEL  7.1392807999
# 15338    15339                     VEHICULO             KENNEDY       7.16156
# 77364    77365                 CONTUNDENTES       12 DE OCTUBRE      7.120159
# 56409    56410  ARMA BLANCA / CORTOPUNZANTE  JOSE ANTONIO GALAN      7.100555
# 5876      5877  ARMA BLANCA / CORTOPUNZANTE           EL PABLÓN      7.182824
#
#               longitud    zona          nom_comuna   ano  mes  dia  \
# 21645       -73.121658  URBANA  03 - SAN FRANCISCO  2012    3   18
# 121611  -73.1190813627  URBANA  03 - SAN FRANCISCO  2020   11    8
# 86506       -73.135289  URBANA     04 - OCCIDENTAL  2017   11   29
# 63791       -73.140084  URBANA     04 - OCCIDENTAL  2016    2   21
# 89972       -73.127253  URBANA   02 - NOR ORIENTAL  2018    3    2
# 96188       -73.108714  URBANA   09 - LA PEDREGOSA  2018    8   21
# 36723       -73.126062  URBANA   02 - NOR ORIENTAL  2013    8   15
# 23179        -73.13518  URBANA     04 - OCCIDENTAL  2012    5    7
# 62607       -73.135247  URBANA     04 - OCCIDENTAL  2016    1   24
# 59429       -73.140686  URBANA          01 - NORTE  2015   10   11
# 21857        -73.13518  URBANA     04 - OCCIDENTAL  2012    3   25
# 25502       -73.135601  URBANA  03 - SAN FRANCISCO  2012    7   21
# 108110    -73.06382146  URBANA  05 - GARCÍA ROVIRA  2019    7   26
# 95244       -73.123122  URBANA   02 - NOR ORIENTAL  2018    7   26
# 60295       -73.135493  URBANA          01 - NORTE  2015   11    8
# 124952  -73.1337279964  URBANA  03 - SAN FRANCISCO  2021    2   15
# 15338       -73.138919  URBANA          01 - NORTE  2011    9    1
# 77364       -73.136057  URBANA     04 - OCCIDENTAL  2017    2   28
# 56409        -73.17085  URBANA  05 - GARCÍA ROVIRA  2015    6   28
# 5876        -73.145244  URBANA          01 - NORTE  2010    9   12
#
#         dia_semana                               descripcion_conducta  \
# 21645            7                  ARTÍCULO 239. HURTO A RESIDENCIAS
# 121611           7                     ARTÍCULO 239. HURTO A PERSONAS
# 86506            3                  ARTÍCULO 111. LESIONES PERSONALES
# 63791            7              ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR
# 89972            5                     ARTÍCULO 239. HURTO A PERSONAS
# 96188            2                     ARTÍCULO 239. HURTO A PERSONAS
# 36723            4              ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR
# 23179            1                  ARTÍCULO 111. LESIONES PERSONALES
# 62607            7                  ARTÍCULO 111. LESIONES PERSONALES
# 59429            7                            ARTÍCULO 103. HOMICIDIO
# 21857            7        ARTÍCULO 239. HURTO A ENTIDADES COMERCIALES
# 25502            6              ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR
# 108110           5                     ARTÍCULO 239. HURTO A PERSONAS
# 95244            4                     ARTÍCULO 239. HURTO A PERSONAS
# 60295            7                  ARTÍCULO 111. LESIONES PERSONALES
# 124952           1                  ARTÍCULO 111. LESIONES PERSONALES
# 15338            4  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 77364            2              ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR
# 56409            7                  ARTÍCULO 111. LESIONES PERSONALES
# 5876             7                  ARTÍCULO 111. LESIONES PERSONALES
#
#                                               conducta clasificaciones delito  \
# 21645                              HURTO A RESIDENCIAS    Lesiones no fatales
# 121611                                HURTO A PERSONAS    Lesiones no fatales
# 86506                              LESIONES PERSONALES    Lesiones no fatales
# 63791                          VIOLENCIA INTRAFAMILIAR    Lesiones no fatales
# 89972                                 HURTO A PERSONAS    Lesiones no fatales
# 96188                                 HURTO A PERSONAS    Lesiones no fatales
# 36723                          VIOLENCIA INTRAFAMILIAR    Lesiones no fatales
# 23179                              LESIONES PERSONALES    Lesiones no fatales
# 62607                              LESIONES PERSONALES    Lesiones no fatales
# 59429                                        HOMICIDIO       Lesiones fatales
# 21857                    HURTO A ENTIDADES COMERCIALES    Lesiones no fatales
# 25502                          VIOLENCIA INTRAFAMILIAR    Lesiones no fatales
# 108110                                HURTO A PERSONAS    Lesiones no fatales
# 95244                                 HURTO A PERSONAS    Lesiones no fatales
# 60295                              LESIONES PERSONALES    Lesiones no fatales
# 124952                             LESIONES PERSONALES    Lesiones no fatales
# 15338   LESIONES CULPOSAS ( EN ACCIDENTE DE TRANSITO )    Lesiones no fatales
# 77364                          VIOLENCIA INTRAFAMILIAR    Lesiones no fatales
# 56409                              LESIONES PERSONALES    Lesiones no fatales
# 5876                               LESIONES PERSONALES    Lesiones no fatales
#
#        edad         curso_de_vida estado_civil_persona     genero  \
# 21645    56           05. Adultez          UNION LIBRE   FEMENINO
# 121611   21           04. Jovenes          UNION LIBRE   FEMENINO
# 86506    30           05. Adultez               CASADO  MASCULINO
# 63791    41           05. Adultez          UNION LIBRE   FEMENINO
# 89972    42           05. Adultez           DIVORCIADO  MASCULINO
# 96188    24           04. Jovenes          UNION LIBRE  MASCULINO
# 36723     2  01. Primera infancia              SOLTERO  MASCULINO
# 23179    33           05. Adultez           DIVORCIADO   FEMENINO
# 62607    27           04. Jovenes               CASADO  MASCULINO
# 59429    21           04. Jovenes              SOLTERO  MASCULINO
# 21857   NaN                   NaN                  NaN        NaN
# 25502    22           04. Jovenes          UNION LIBRE   FEMENINO
# 108110   24           04. Jovenes              SOLTERO   FEMENINO
# 95244    41           05. Adultez          UNION LIBRE  MASCULINO
# 60295    45           05. Adultez               CASADO  MASCULINO
# 124952   29           05. Adultez                  NaN  MASCULINO
# 15338    24           04. Jovenes              SOLTERO  MASCULINO
# 77364    37           05. Adultez              SOLTERO  MASCULINO
# 56409    19           04. Jovenes              SOLTERO  MASCULINO
# 5876     25           04. Jovenes              SOLTERO  MASCULINO
#
#                 movil_agresor          movil_victima
# 21645                   A PIE                  A PIE
# 121611  CONDUCTOR MOTOCICLETA                  A PIE
# 86506                   A PIE                  A PIE
# 63791                   A PIE                  A PIE
# 89972                   A PIE  CONDUCTOR MOTOCICLETA
# 96188    PASAJERO MOTOCICLETA  CONDUCTOR MOTOCICLETA
# 36723                   A PIE                  A PIE
# 23179                   A PIE                  A PIE
# 62607                   A PIE                  A PIE
# 59429                   A PIE                  A PIE
# 21857                   A PIE                  A PIE
# 25502                   A PIE                  A PIE
# 108110                  A PIE                  A PIE
# 95244                   A PIE         CONDUCTOR TAXI
# 60295                   A PIE  CONDUCTOR MOTOCICLETA
# 124952                  A PIE                  A PIE
# 15338          CONDUCTOR TAXI  CONDUCTOR MOTOCICLETA
# 77364                   A PIE                  A PIE
# 56409                   A PIE                  A PIE
# 5876                    A PIE                  A PIE

# %%
delitos_barrios = delitos.groupby(["barrios_hecho"]).size().to_frame("quantity")
#delitos_barrios.to_csv("delitos_barrios.csv")

# %%
delitos_genero = delitos.groupby(["barrios_hecho","genero"]).size().to_frame("quantity")
#delitos_genero.to_csv("delitos_genero.csv")

# %%
delitos_edad = delitos.groupby(["barrios_hecho","curso_de_vida"]).size().to_frame("quantity")
#delitos_edad.to_csv("delitos_edad.csv")

# %%
delitos_clasificacion = delitos.groupby(["barrios_hecho","clasificaciones delito"]).size().to_frame("quantity")
#delitos_clasificacion.to_csv("delitos_clasificacion.csv")

# %%
delitos_ano = delitos.groupby(["barrios_hecho","ano"]).size().to_frame("quantity")
#delitos_ano.to_csv("delitos_ano.csv")

# %%
dicc_cond = {"HURTO A PERSONAS":"HURTO",
             "HURTO A ENTIDADES COMERCIALES":"HURTO",
             "HURTO A RESIDENCIAS":"HURTO",
             "HURTO A MOTOCICLETAS":"HURTO",
             "HURTO A AUTOMOTORES":"HURTO",
             "HURTO A ABIGEATO":"HURTO",
             "HURTO A PIRATERÍA TERRESTRE":"HURTO",
             "ACTOS SEXUALES CON MENOR DE 14 AÑOS":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL ABUSIVO CON MENOR DE 14 AÑOS":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL VIOLENTO":"DELITOS SEXUALES O PROSTITUCION",
             "ACTO SEXUAL VIOLENTO":"DELITOS SEXUALES O PROSTITUCION",
             "ACOSO SEXUAL":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL O ACTO SEXUAL ABUSIVO CON INCAPAZ DE RESISTIR":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL O ACTO SEXUAL EN PERSONA PUESTA EN INCAPACIDAD DE RESISTIR":"DELITOS SEXUALES O PROSTITUCION",
             "PORNOGRAFÍA CON MENORES":"DELITOS SEXUALES O PROSTITUCION",
             "UTILIZACIÓN O FACILITACIÓN DE MEDIOS DE COMUNICACIÓN PARA OFRECER SERVICIOS SEXUALES DE MENORES":"DELITOS SEXUALES O PROSTITUCION",
             "INDUCCIÓN A LA PROSTITUCIÓN":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL ABUSIVO CON MENOR DE 14 AÑOS (CIRCUNSTANCIAS AGRAVACIÓN)":"DELITOS SEXUALES O PROSTITUCION",
             "ACTOS SEXUALES CON MENOR DE 14 AÑOS (CIRCUNSTANCIAS DE AGRAVACIÓN)":"DELITOS SEXUALES O PROSTITUCION",
             "ACTO SEXUAL VIOLENTO (CIRCUNSTANCIAS DE AGRAVACIÓN)":"DELITOS SEXUALES O PROSTITUCION",
             "ACCESO CARNAL VIOLENTO (CIRCUNSTANCIAS AGRAVACIÓN)":"DELITOS SEXUALES O PROSTITUCION",
             "CONSTREÑIMIENTO A LA PROSTITUCIÓN ":"DELITOS SEXUALES O PROSTITUCION",
             "PROXENETISMO CON MENOR DE EDAD":"DELITOS SEXUALES O PROSTITUCION",
             "DEMANDA DE EXPLOTACION SEXUAL COMERCIAL DE PERSONA MENOR DE 18 AÑOS DE EDAD":"DELITOS SEXUALES O PROSTITUCION",
             "ESTÍMULO A LA PROSTITUCIÓN DE MENORES":"DELITOS SEXUALES O PROSTITUCION",
             "CONSTREÑIMIENTO A LA PROSTITUCIÓN":"DELITOS SEXUALES O PROSTITUCION",
             "HOMICIDIO":"OTROS",
             "HOMICIDIO CULPOSO ( EN ACCIDENTE DE TRÁNSITO)":"OTROS",
             "EXTORSIÓN":"OTROS",
             "AMENAZAS":"OTROS",
             "FEMINICIDIO":"OTROS",
             "SECUESTRO SIMPLE":"OTROS",
             "INCAPACIDAD PARA TRABAJAR O ENFERMEDAD":"OTROS",
             "LESIONES AL FETO":"OTROS",
             "LESIONES PERSONALES ( CIRCUNSTANCIAS DE AGRAVACIÓN)":"OTROS"
             }

# %%
delitos["conducta"] = delitos["conducta"].replace(dicc_cond)
# Out:
# /var/folders/s2/7zt_5m2d2nv76vq_ybqf9csm0000gn/T/ipykernel_9252/1534442088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delitos["conducta"] = delitos["conducta"].replace(dicc_cond)

# %%
delitos_conducta = delitos.groupby(["barrios_hecho","conducta"]).size().to_frame("quantity")
delitos_conducta.to_csv("delitos_conducta.csv")
delitos_conducta
# Out:
#                                                               quantity
# barrios_hecho conducta
# 12 DE OCTUBRE DELITOS SEXUALES O PROSTITUCION                       10
#               HURTO                                                 76
#               LESIONES CULPOSAS ( EN ACCIDENTE DE TRANSITO )        14
#               LESIONES PERSONALES                                   76
#               OTROS                                                  9
# ...                                                                ...
# ZARABANDA     DELITOS SEXUALES O PROSTITUCION                       15
#               HURTO                                                 54
#               LESIONES PERSONALES                                   62
#               OTROS                                                 18
#               VIOLENCIA INTRAFAMILIAR                               57
#
# [498 rows x 1 columns]

# %%
#geojson = gpd.read_file("https://raw.githubusercontent.com/Joaron4/team211_datasets/main/Barrios-polygon.geojson", driver = "GeoJSON")
